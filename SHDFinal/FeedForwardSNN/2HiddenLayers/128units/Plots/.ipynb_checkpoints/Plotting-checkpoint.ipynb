# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
open_file = open("list128_2layersTEST1RUN1.pkl","rb")
a = pickle.load(open_file)
open_file = open("list128_2layersTEST1RUN2.pkl","rb")
b = pickle.load(open_file)
a.extend(b)
open_file = open("list128_2layersTEST1RUN3.pkl","rb")
b = pickle.load(open_file)
a.extend(b)
open_file = open("list128_2layersTEST1RUN4.pkl","rb")
b = pickle.load(open_file)
a.extend(b)
open_file = open("list128_2layersTEST1RUN5.pkl","rb")
b = pickle.load(open_file)
a.extend(b)
open_file = open("list128_2layersTEST1RUN6.pkl","rb")
b = pickle.load(open_file)
a.extend(b)
open_file = open("list128_2layersTEST1RUN7.pkl","rb")
b = pickle.load(open_file)
a.extend(b)

# %%
x = range(0,len(a))

# %%
plt.plot(x,a)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('FF2Layers128unitsTest1')
plt.show()
