# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
open_file = open("list256_recurrentnormalTEST1RUN1.pkl","rb")
a = pickle.load(open_file)
open_file = open("list256_recurrentnormalTEST1RUN2.pkl","rb")
b = pickle.load(open_file)
a.extend(b)
open_file = open("list256_recurrentnormalTEST1RUN3.pkl","rb")
b = pickle.load(open_file)
a.extend(b)

# %%
x = range(0,len(a))

# %%
plt.plot(x,a)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('RSNNNormal256unitsTest1')
plt.show()
